# %%
import typing
import pathlib

import rich.progress
import pandas
import cltrier_lib

# %%
DATA_PATH: str = "../../../data"
EXPORT_PATH: str = f"{DATA_PATH}/processed/twitter.english.dataset.enriched.csv"

# %%
dataset: pandas.DataFrame = (
    pandas.merge(
        pandas.read_csv(f"{DATA_PATH}/interim/twitter.english.replies.csv", index_col=0),
        pandas.read_csv(f"{DATA_PATH}/interim/twitter.english.posts.csv", index_col=0),
        how="left",
        left_on="reply_to_id",
        right_on="id",
        suffixes=("_reply", "_post")
    )
    .rename(columns=dict(username="author_post", first_name="author_first_name_post", last_name="author_last_name_post", party="author_party_post"))
    [["id_post", "id_reply", "author_id_post", "author_id_reply", "author_first_name_post", "author_last_name_post", "author_party_post", "text_post", "text_reply"]]
)
dataset
# Out:
#                   id_post             id_reply  author_id_post  \
# 0     1684217285567807488  1684217285567807488       131546062
# 1     1682471504880050176  1682471504880050176       131546062
# 2     1682337371126112512  1682337371126112512       131546062
# 3     1681994109094080512  1681994109094080512       131546062
# 4     1681424977076322304  1681424977076322304       131546062
# ...                   ...                  ...             ...
# 7084  1672603841127170048  1672603841127170048       278145569
# 7085  1667892656184127488  1667892656184127488       432895323
# 7086  1687486482334855168  1687486482334855168       278145569
# 7087  1592717086605852672  1592717086605852672       432895323
# 7088  1670790352247091200  1670790352247091200      1080844782
#
#           author_id_reply author_first_name_post author_last_name_post  \
# 0     1088163738950295552                   Rick                 Scott
# 1     1088163738950295552                   Rick                 Scott
# 2     1088163738950295552                   Rick                 Scott
# 3     1088163738950295552                   Rick                 Scott
# 4     1088163738950295552                   Rick                 Scott
# ...                   ...                    ...                   ...
# 7084           1411161121                 Marsha             Blackburn
# 7085           1411161121                Lindsey                Graham
# 7086             28261183                 Marsha             Blackburn
# 7087             28261183                Lindsey                Graham
# 7088            228919093                Kyrsten                Sinema
#
#      author_party_post                                          text_post  \
# 0     Republican Party  Democrats scream every day about limiting Amer...
# 1     Republican Party  If our economy is doing as well as @JoeBiden s...
# 2     Republican Party  Bottom line: our military should be focused on...
# 3     Republican Party  I'm fighting for amendments in the FY 24 NDAA ...
# 4     Republican Party  Why is the White House acting like America's i...
# ...                ...                                                ...
# 7084  Republican Party  Imagine the consequences if a Republican presi...
# 7085  Republican Party  Most Republicans believe we live in a country ...
# 7086  Republican Party  Why are all of these indictments coming out ag...
# 7087  Republican Party  If President Trump continues this tone and del...
# 7088  Democratic Party  Today is #Juneteenth - marking 158 years since...
#
#                                              text_reply
# 0     Funny that Hunter is being held to account yet...
# 1                                          You’re lying
# 2     Why don’t you call Senator Tubberville and tel...
# 3     OK folks let’s get your shot glasses out and w...
# 4                                        Blah blah blah
# ...                                                 ...
# 7084  I'll guarantee that if any one of yours or you...
# 7085  Most Republicans threw away their beliefs when...
# 7086  Because our legal system sucks like our govern...
# 7087  Republicans AGAINST tRUMP, Voted against him o...
# 7088  Ummm, wrong.  It is the commemoration of the d...
#
# [7089 rows x 9 columns]

# %%
dataset.to_csv(EXPORT_PATH.replace(".enriched", ""))

# %%
topic_extraction_instruction: str = """Your task is to extract the main topics of the given tweet. Summarize topics exceeding 10 characters. Keep the total number of topics to 3 or fewer. 

Respond only with the topic names separated by commas. Omit any justification. This is the tweet: 
"""

# %%
for new_col, source_col, instruction in [
    ("topics_post", "text_post", topic_extraction_instruction),
    ("topics_reply", "text_reply", topic_extraction_instruction),
]:  
    
    if pathlib.Path(EXPORT_PATH).is_file():
        dataset = pandas.read_csv(EXPORT_PATH, index_col=0)

    if new_col not in dataset.columns:
        
        predictions: typing.List[str] = [
            cltrier_lib.inference.Pipeline()(
                chat= cltrier_lib.inference.schemas.Chat(messages=[
                    cltrier_lib.inference.schemas.Message(role="system", content=instruction),
                    cltrier_lib.inference.schemas.Message(role="user", content=content)
                ])
            )[-1].content
            for content in rich.progress.track(dataset[source_col])
        ]

        dataset = dataset.assign(**{new_col: predictions})
        dataset.to_csv(EXPORT_PATH)
    
    display(dataset[new_col].value_counts())
# Out:
# Output()

# %%
# manual (human) filtering and reduction of topics, comparison and unification with topics_reply to improve the dataset quality
list(dataset["topics_post"].str.split(",").explode().str.strip().drop_duplicates())
