# %%
import typing 
import pandas 
import seaborn

SEED: int = 1
METRICS: typing.List[str] = ["public_metrics.impression_count", "public_metrics.like_count", "public_metrics.retweet_count", "public_metrics.reply_count"]

# %%
dataset: pandas.DataFrame = (
    pandas.read_csv("../data/raw/twitter.german/GermanyMdBTweets_2023.csv", index_col=0)
    # exclude retweets
    .pipe(lambda _df: _df[~_df["text"].str.contains("RT")])
    # exclude tweets that start with a mention
    .pipe(lambda _df: _df[~_df["text"].str.startswith("@")])
    # exclude tweets with urls
    .pipe(lambda _df: _df[~_df["text"].str.contains("https://")])
    # exclude tweets that are short than 32 characters
    .pipe(lambda _df: _df[_df["text"].str.len() > 32])
)
dataset
# Out:
#                          id            author_id      conversation_id  \
# 2       1625441437167849472  1001837201276235777  1625441437167849472
# 3       1661308051817635841  1001837201276235777  1661308051817635841
# 5       1623983333993594883  1001837201276235777  1623983333993594883
# 8       1663462991122124802  1001837201276235777  1663462991122124802
# 9       1618208860636090368  1001837201276235777  1618208860636090368
# ...                     ...                  ...                  ...
# 154724  1613432190171336706   997138767763750912  1613432190171336706
# 154735  1623988232596647936   997138767763750912  1623988232596647936
# 154768  1631697592986763277   997138767763750912  1631697592986763277
# 154777  1656776953175719938   997138767763750912  1656776953175719938
# 154780  1632081709771497473   997138767763750912  1632081709771497473
#
#                                                      text  \
# 2       Die verheerenden Folgen des Erdbebens in #Syri...
# 3       Noch immer sind 50 Millionen Menschen Opfer mo...
# 5       Im #Bundestag haben wir heute den #PlanungsPus...
# 8       Gewaltausbruch im #Kosovo &amp; Angriff auf #K...
# 9       #Russland muss seine Bürger wegen #Menschenrec...
# ...                                                   ...
# 154724  Es ist dringend geboten, denen zu danken 🙏, di...
# 154735  Mehr Tempo bei der Infrastruktur! Im #Bundesta...
# 154768  Wie erreichen wir die CO2-Neutralität der Best...
# 154777  Das #GEG ist ein handwerklich schlechtes Geset...
# 154780  Aus Anlass: der #ETS sollte schnellstmöglich a...
#
#         public_metrics.retweet_count  public_metrics.reply_count  \
# 2                                 16                          19
# 3                                  3                           0
# 5                                  3                          10
# 8                                  2                           2
# 9                                  6                           2
# ...                              ...                         ...
# 154724                             2                           0
# 154735                             1                           0
# 154768                             1                           2
# 154777                            26                          53
# 154780                             1                           6
#
#         public_metrics.like_count  public_metrics.quote_count  \
# 2                              46                           1
# 3                               6                           0
# 5                              10                           0
# 8                               6                           0
# 9                              20                           0
# ...                           ...                         ...
# 154724                          9                           0
# 154735                          5                           0
# 154768                          3                           0
# 154777                         91                           4
# 154780                         16                           0
#
#         public_metrics.impression_count  public_metrics.bookmark_count  \
# 2                                  3104                            NaN
# 3                                   297                            0.0
# 5                                   573                            NaN
# 8                                   651                            0.0
# 9                                  1094                            NaN
# ...                                 ...                            ...
# 154724                              989                            NaN
# 154735                              492                            NaN
# 154768                              441                            NaN
# 154777                             5944                            0.0
# 154780                             1943                            NaN
#
#                       created_at        username
# 2       2023-02-14T10:26:52.000Z   RenataAlt_MdB
# 3       2023-05-24T09:47:59.000Z   RenataAlt_MdB
# 5       2023-02-10T09:52:53.000Z   RenataAlt_MdB
# 8       2023-05-30T08:30:57.000Z   RenataAlt_MdB
# 9       2023-01-25T11:27:11.000Z   RenataAlt_MdB
# ...                          ...             ...
# 154724  2023-01-12T07:06:24.000Z  HerbrandMarkus
# 154735  2023-02-10T10:12:21.000Z  HerbrandMarkus
# 154768  2023-03-03T16:46:36.000Z  HerbrandMarkus
# 154777  2023-05-11T21:43:01.000Z  HerbrandMarkus
# 154780  2023-03-04T18:12:56.000Z  HerbrandMarkus
#
# [16707 rows x 12 columns]

# %%
# calculate the distribution of replies
post_reply_dist: pandas.Series = dataset["public_metrics.reply_count"].value_counts().describe(percentiles=[.25, .5, .75, .8, .85, .9, .95])
post_reply_dist
# Out:
# count     859.000000
# mean       19.449360
# std       171.168766
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# 80%         6.000000
# 85%         8.000000
# 90%        15.000000
# 95%        30.100000
# max      3762.000000
# Name: count, dtype: float64

# %%
# generate a subset containing only the 90% most commented tweets
dataset = dataset[dataset["public_metrics.reply_count"] > post_reply_dist.loc["90%"]]
len(dataset)
# Out:
# 4367

# %%
# calculate the distribution of user activity (number of posts)
user_activity_dist: pandas.Series = dataset["username"].value_counts().describe(percentiles=[.25, .5, .75, .8, .85, .9, .95])
user_activity_dist
# Out:
# count    316.000000
# mean      13.819620
# std       30.475633
# min        1.000000
# 25%        1.000000
# 50%        4.000000
# 75%       12.000000
# 80%       15.000000
# 85%       19.000000
# 90%       33.500000
# 95%       55.250000
# max      299.000000
# Name: count, dtype: float64

# %%
sampled_dataset: pandas.DataFrame = (
    dataset
    [   
        # select only the 80% most active users
        dataset["username"].isin(
            list((dataset["username"].value_counts() > user_activity_dist.loc["80%"]).pipe(lambda _s : _s[_s]).index)
        )
    ]
    .groupby("username")
    # sample by number of least active 80%' user posts
    .sample(n=int(user_activity_dist.loc["80%"]), random_state=SEED)
)

len(sampled_dataset), len(sampled_dataset["username"].unique())
# Out:
# (915, 61)

# %%
(
    sampled_dataset
    .assign(text=sampled_dataset["text"].replace("\n","", regex=True))
    [["id", "author_id", "conversation_id", "text", "created_at", "username"]]
    .to_csv("../data/interim/twitter.german.posts.csv")
)

# %%
(
    sampled_dataset
    [["username", *METRICS]]
    .groupby("username")
    .agg([
        "min",
        "max",
        "mean",
        "std",
    ])
    .sort_values(by=("public_metrics.like_count", "mean"), ascending=False)
    .round(3)
)
# Out:
#                 public_metrics.impression_count                      \
#                                             min     max        mean
# username
# Alice_Weidel                              19222  262690   90278.800
# YeOne_Rhie                                 1741  170457   47011.533
# Beatrix_vStorch                            9369   87306   46221.467
# n_roettgen                                 6075  312003   58976.400
# vonderleyen                               34613  587670  212754.400
# ...                                         ...     ...         ...
# KatjaMast                                   996  111460   22568.267
# katdro                                     1226   73407   13978.200
# Ralf_Stegner                               2613  534757   72865.867
# b_riexinger                                2890   54123   12012.600
# starkwatzinger                             9044  204448   41009.800
#
#                             public_metrics.like_count                   \
#                         std                       min    max      mean
# username
# Alice_Weidel      58931.420                      1530  12771  5467.667
# YeOne_Rhie        57761.120                       218   9321  3205.400
# Beatrix_vStorch   27501.427                       452   4828  2441.800
# n_roettgen        97935.512                       174  16133  2354.333
# vonderleyen      170478.846                       211  10394  2328.533
# ...                     ...                       ...    ...       ...
# KatjaMast         34729.107                        16   1154   188.733
# katdro            19472.357                        17    958   174.800
# Ralf_Stegner     147732.414                        20   1185   167.933
# b_riexinger       13557.779                        30    622   159.667
# starkwatzinger    50650.703                        47    365   154.067
#
#                           public_metrics.retweet_count                  \
#                       std                          min   max      mean
# username
# Alice_Weidel     2850.072                          181  1697   735.333
# YeOne_Rhie       3197.305                           66  4595  1414.467
# Beatrix_vStorch  1511.466                           65   838   334.867
# n_roettgen       4100.973                           19  7555   813.067
# vonderleyen      2769.419                           42  1770   459.667
# ...                   ...                          ...   ...       ...
# KatjaMast         307.530                            1   173    26.333
# katdro            244.469                            1   162    25.600
# Ralf_Stegner      297.267                            1   194    22.533
# b_riexinger       177.599                            3    87    22.467
# starkwatzinger     96.396                            7    41    20.733
#
#                           public_metrics.reply_count
#                       std                        min   max     mean      std
# username
# Alice_Weidel      422.270                         46  1034  360.533  253.855
# YeOne_Rhie       1605.003                         16   618  189.667  214.395
# Beatrix_vStorch   228.672                         63   674  312.533  218.498
# n_roettgen       1915.388                         18  3270  337.733  851.972
# vonderleyen       473.109                         59  2893  963.533  965.603
# ...                   ...                        ...   ...      ...      ...
# KatjaMast          44.815                         20  1362  242.000  448.218
# katdro             41.226                         16   737  141.467  230.341
# Ralf_Stegner       48.940                         20  1838  329.333  535.416
# b_riexinger        22.919                         17   507   89.067  119.472
# starkwatzinger     10.340                         19   635  193.733  186.403
#
# [61 rows x 16 columns]

# %%
grid = seaborn.FacetGrid(
    data = (
        sampled_dataset[METRICS]
        .melt(var_name="metric", value_name="count")
        .pipe(lambda _df: _df.assign(metric=_df["metric"].str.replace("public_metrics.", "")))
    ),
    col="metric",
    sharey=False
)
grid.map_dataframe(seaborn.boxplot, y="count", showfliers=False)
